# %%
import pandas as pd
games = pd.read_csv("ign.csv")
games.drop(['Unnamed: 0','url'],axis=1,inplace=True)

# %%
games.sample(10)
# Out:
#       score_phrase                                title          platform  \
# 6480         Great  Final Fantasy I & II: Dawn of Souls  Game Boy Advance
# 16663         Okay                            Max Payne            iPhone
# 10330        Great         EverQuest II: Rise of Kunark                PC
# 10535     Mediocre    Dance Dance Revolution Universe 2          Xbox 360
# 6710          Okay                                 NARC              Xbox
# 2420         Great                               Seaman         Dreamcast
# 4974       Amazing          Virtua Fighter 4: Evolution     PlayStation 2
# 2456          Okay       Ganbare! Nippon! Olympics 2000         Dreamcast
# 12091         Okay  Boogerman: A Pick & Flick Adventure           Genesis
# 4297          Okay               Ty the Tasmanian Tiger          GameCube
#
#        score             genre editors_choice  release_year  release_month  \
# 6480     8.5  RPG, Compilation              Y          2004             11
# ...
